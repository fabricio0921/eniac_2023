# %%
! pip install --upgrade pandas
! pip install -U imbalanced-learn
! pip install openml
! pip install tqdm
! pip install rpy2
import pandas as pd
import numpy as np
import os
from imblearn.over_sampling import ADASYN, SMOTE, SMOTEN, SVMSMOTE
from imblearn.under_sampling import NearMiss, ClusterCentroids
from sklearn.metrics import accuracy_score, f1_score
import decodIRT_OtML as dIRT_OtML
import decodIRT_MLtIRT as dIRT_MLtIRT
import sys


def get_classication(resp,y):
    tmp = []
    for c,i in enumerate(y):
        if resp[c] == 1:
            tmp.append(i)
        elif i == 1:
            tmp.append(0)
        elif i == 0:
            tmp.append(1)
    return tmp

list_Datasets = ['ilpd','climate-model-simulation-crashes','credit-approval']

list_seeds = [10,20,30]
list_seeds_mtd = [10,20,30]

#list_over = ['adasyn','smote']
list_over = ['adasyn','smote','smoten','svmsmote','sem_nada']

list_clfs = ['GaussianNB','KNeighborsClassifier(8)','DecisionTreeClassifier()','RandomForestClassifier','SVM','MLPClassifier']
list_clfs_index = [0,5,6,9,10,11]

main_path = os.getcwd()+'/'

dict_scores = {}

for dataset in list_Datasets:
  dict_scores[dataset] = {}
  for seed_value in list_seeds:
    dict_scores[dataset]['seed_'+str(seed_value)] = {}
    for mtd_over in list_over:
      dict_scores[dataset]['seed_'+str(seed_value)][mtd_over] = {}
      for seed_mtd in list_seeds:
        #print('Calculando scores para {} seed {} do metodo {} do seed {}'.format(dataset,seed_value,mtd_over,seed_mtd))
        if mtd_over == 'sem_nada':
            path_result = dataset
        else:
            path_result = dataset+'_over_'+mtd_over+'_'+str(seed_mtd)

        df = pd.read_csv('seed_'+str(seed_value)+'/'+path_result+'/'+'acc_f1_score.csv', index_col=0)
        df_dict = df.transpose().to_dict()
        dict_scores[dataset]['seed_'+str(seed_value)][mtd_over]['seed_mtd_'+str(seed_mtd)] = df_dict

print('normal')
print(dict_scores['ilpd']['seed_10']['sem_nada'])

dict_media_metd = {}

for dataset in list_Datasets:
  dict_media_metd[dataset] = {}
  for seed_value in list_seeds:
    dict_media_metd[dataset]['seed_'+str(seed_value)] = {}
    for mtd_over in list_over:
        dict_media_metd[dataset]['seed_'+str(seed_value)][mtd_over] = {}
        for clf in list_clfs:
            list_acc = [dict_scores[dataset]['seed_'+str(seed_value)][mtd_over][i][clf]['acc_score'] for i in dict_scores[dataset]['seed_'+str(seed_value)][mtd_over]]
            list_f1 = [dict_scores[dataset]['seed_'+str(seed_value)][mtd_over][i][clf]['f1_score'] for i in dict_scores[dataset]['seed_'+str(seed_value)][mtd_over]]

            tmp = {'acc_score':{'media':np.mean(list_acc), 'mediana':np.median(list_acc), 'desvio':np.std(list_acc)},
                'f1_score':{'media':np.mean(list_f1), 'mediana':np.median(list_f1), 'desvio':np.std(list_f1)}}
            dict_media_metd[dataset]['seed_'+str(seed_value)][mtd_over][clf] = tmp

print('teste media')
print(dict_media_metd['ilpd']['seed_10']['sem_nada'])

dict_media_seed = {}

for dataset in list_Datasets:
    dict_media_seed[dataset] = {}
    for mtd_over in list_over:
        dict_media_seed[dataset][mtd_over] = {}
        for clf in list_clfs:
            list_acc = [dict_media_metd[dataset]['seed_'+str(i)][mtd_over][clf]['acc_score']['media'] for i in list_seeds]
            list_f1 = [dict_media_metd[dataset]['seed_'+str(i)][mtd_over][clf]['f1_score']['media'] for i in list_seeds]
            
            tmp = {'acc_score':{'media':np.mean(list_acc), 'mediana':np.median(list_acc), 'desvio':np.std(list_acc)},
                'f1_score':{'media':np.mean(list_f1), 'mediana':np.median(list_f1), 'desvio':np.std(list_f1)}}
            dict_media_seed[dataset][mtd_over][clf] = tmp

print('teste media seed')
print(dict_media_seed['ilpd']['adasyn']['GaussianNB']['f1_score']['media'])
# Out:
# Requirement already up-to-date: pandas in /home/fabricio/.local/lib/python3.8/site-packages (2.0.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.20.3; python_version < "3.10" in /home/fabricio/.local/lib/python3.8/site-packages (from pandas) (1.24.3)
# Requirement already satisfied, skipping upgrade: pytz>=2020.1 in /home/fabricio/.local/lib/python3.8/site-packages (from pandas) (2023.3)
# Requirement already satisfied, skipping upgrade: tzdata>=2022.1 in /home/fabricio/.local/lib/python3.8/site-packages (from pandas) (2023.3)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.8.2 in /home/fabricio/.local/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.14.0)
# Requirement already up-to-date: imbalanced-learn in /home/fabricio/.local/lib/python3.8/site-packages (0.10.1)
# Requirement already satisfied, skipping upgrade: joblib>=1.1.1 in /home/fabricio/.local/lib/python3.8/site-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied, skipping upgrade: scikit-learn>=1.0.2 in /home/fabricio/.local/lib/python3.8/site-packages (from imbalanced-learn) (1.2.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.17.3 in /home/fabricio/.local/lib/python3.8/site-packages (from imbalanced-learn) (1.24.3)
# Requirement already satisfied, skipping upgrade: scipy>=1.3.2 in /home/fabricio/.local/lib/python3.8/site-packages (from imbalanced-learn) (1.10.1)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in /home/fabricio/.local/lib/python3.8/site-packages (from imbalanced-learn) (3.1.0)
# Requirement already satisfied: openml in /home/fabricio/.local/lib/python3.8/site-packages (0.13.1)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from openml) (2.22.0)
# Requirement already satisfied: numpy>=1.6.2 in /home/fabricio/.local/lib/python3.8/site-packages (from openml) (1.24.3)
# Requirement already satisfied: liac-arff>=2.4.0 in /home/fabricio/.local/lib/python3.8/site-packages (from openml) (2.5.0)
# Requirement already satisfied: pyarrow in /home/fabricio/.local/lib/python3.8/site-packages (from openml) (12.0.0)
# Requirement already satisfied: python-dateutil in /home/fabricio/.local/lib/python3.8/site-packages (from openml) (2.8.2)
# Requirement already satisfied: pandas>=1.0.0 in /home/fabricio/.local/lib/python3.8/site-packages (from openml) (2.0.1)
# Requirement already satisfied: scikit-learn>=0.18 in /home/fabricio/.local/lib/python3.8/site-packages (from openml) (1.2.2)
# Requirement already satisfied: xmltodict in /home/fabricio/.local/lib/python3.8/site-packages (from openml) (0.13.0)
# Requirement already satisfied: minio in /home/fabricio/.local/lib/python3.8/site-packages (from openml) (7.1.14)
# Requirement already satisfied: scipy>=0.13.3 in /home/fabricio/.local/lib/python3.8/site-packages (from openml) (1.10.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil->openml) (1.14.0)
# Requirement already satisfied: tzdata>=2022.1 in /home/fabricio/.local/lib/python3.8/site-packages (from pandas>=1.0.0->openml) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /home/fabricio/.local/lib/python3.8/site-packages (from pandas>=1.0.0->openml) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/fabricio/.local/lib/python3.8/site-packages (from scikit-learn>=0.18->openml) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /home/fabricio/.local/lib/python3.8/site-packages (from scikit-learn>=0.18->openml) (1.2.0)
# Requirement already satisfied: urllib3 in /usr/lib/python3/dist-packages (from minio->openml) (1.25.8)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from minio->openml) (2019.11.28)
# Requirement already satisfied: tqdm in /home/fabricio/.local/lib/python3.8/site-packages (4.65.0)
# Collecting rpy2
#   Using cached rpy2-3.5.11.tar.gz (216 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting tzlocal
#   Downloading tzlocal-5.0.1-py3-none-any.whl (20 kB)
# Collecting cffi>=1.10.0
#   Using cached cffi-1.15.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (442 kB)
# Requirement already satisfied: pytz in /home/fabricio/.local/lib/python3.8/site-packages (from rpy2) (2023.3)
# Collecting jinja2
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 270 kB/s eta 0:00:01
# Collecting backports.zoneinfo; python_version < "3.9"
#   Downloading backports.zoneinfo-0.2.1-cp38-cp38-manylinux1_x86_64.whl (74 kB)
#      |████████████████████████████████| 74 kB 375 kB/s eta 0:00:01
# Collecting pycparser
#   Using cached pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Building wheels for collected packages: rpy2
#   Building wheel for rpy2 (PEP 517) ... done
#   Created wheel for rpy2: filename=rpy2-3.5.11-py3-none-any.whl size=218492 sha256=2c96c50c3b3ee531362b3776ae374c70eced6425f1f072b7c43454fb41e34fdd
#   Stored in directory: /home/fabricio/.cache/pip/wheels/7c/b7/d8/a647fa8f7b4b20dfcb940f0fb976376fc369bffff7949c75f2
# Successfully built rpy2
# Installing collected packages: backports.zoneinfo, tzlocal, pycparser, cffi, MarkupSafe, jinja2, rpy2
# Successfully installed MarkupSafe-2.1.2 backports.zoneinfo-0.2.1 cffi-1.15.1 jinja2-3.1.2 pycparser-2.21 rpy2-3.5.11 tzlocal-5.0.1
# normal
# {'seed_mtd_10': {'GaussianNB': {'acc_score': 0.6, 'f1_score': 0.5833333333333334}, 'KNeighborsClassifier(8)': {'acc_score': 0.72, 'f1_score': 0.2222222222222222}, 'DecisionTreeClassifier()': {'acc_score': 0.6857142857142857, 'f1_score': 0.3678160919540229}, 'RandomForestClassifier': {'acc_score': 0.72, 'f1_score': 0.3098591549295775}, 'SVM': {'acc_score': 0.7142857142857143, 'f1_score': 0.0}, 'MLPClassifier': {'acc_score': 0.7028571428571428, 'f1_score': 0.3157894736842105}}, 'seed_mtd_20': {'GaussianNB': {'acc_score': 0.6, 'f1_score': 0.5833333333333334}, 'KNeighborsClassifier(8)': {'acc_score': 0.72, 'f1_score': 0.2222222222222222}, 'DecisionTreeClassifier()': {'acc_score': 0.6857142857142857, 'f1_score': 0.3678160919540229}, 'RandomForestClassifier': {'acc_score': 0.72, 'f1_score': 0.3098591549295775}, 'SVM': {'acc_score': 0.7142857142857143, 'f1_score': 0.0}, 'MLPClassifier': {'acc_score': 0.7028571428571428, 'f1_score': 0.3157894736842105}}, 'seed_mtd_30': {'GaussianNB': {'acc_score': 0.6, 'f1_score': 0.5833333333333334}, 'KNeighborsClassifier(8)': {'acc_score': 0.72, 'f1_score': 0.2222222222222222}, 'DecisionTreeClassifier()': {'acc_score': 0.6857142857142857, 'f1_score': 0.3678160919540229}, 'RandomForestClassifier': {'acc_score': 0.72, 'f1_score': 0.3098591549295775}, 'SVM': {'acc_score': 0.7142857142857143, 'f1_score': 0.0}, 'MLPClassifier': {'acc_score': 0.7028571428571428, 'f1_score': 0.3157894736842105}}}
# teste media
# {'GaussianNB': {'acc_score': {'media': 0.6, 'mediana': 0.6, 'desvio': 0.0}, 'f1_score': {'media': 0.5833333333333334, 'mediana': 0.5833333333333334, 'desvio': 0.0}}, 'KNeighborsClassifier(8)': {'acc_score': {'media': 0.7200000000000001, 'mediana': 0.72, 'desvio': 1.1102230246251565e-16}, 'f1_score': {'media': 0.2222222222222222, 'mediana': 0.2222222222222222, 'desvio': 0.0}}, 'DecisionTreeClassifier()': {'acc_score': {'media': 0.6857142857142856, 'mediana': 0.6857142857142857, 'desvio': 1.1102230246251565e-16}, 'f1_score': {'media': 0.3678160919540228, 'mediana': 0.3678160919540229, 'desvio': 5.551115123125783e-17}}, 'RandomForestClassifier': {'acc_score': {'media': 0.7200000000000001, 'mediana': 0.72, 'desvio': 1.1102230246251565e-16}, 'f1_score': {'media': 0.3098591549295775, 'mediana': 0.3098591549295775, 'desvio': 0.0}}, 'SVM': {'acc_score': {'media': 0.7142857142857143, 'mediana': 0.7142857142857143, 'desvio': 0.0}, 'f1_score': {'media': 0.0, 'mediana': 0.0, 'desvio': 0.0}}, 'MLPClassifier': {'acc_score': {'media': 0.7028571428571428, 'mediana': 0.7028571428571428, 'desvio': 0.0}, 'f1_score': {'media': 0.3157894736842105, 'mediana': 0.3157894736842105, 'desvio': 0.0}}}
# teste media seed
# 0.565535088919287
